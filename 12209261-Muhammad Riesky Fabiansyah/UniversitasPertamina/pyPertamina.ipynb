# %%
# x = 5
# print(type(x))
# y = 0.5
# print(type(y))
# mobil = "hijau"
# print(type(mobil))

# print("pertamina" + "Indonesia")
# print("Universitas Pertamina " * 2)

# (5*2) > (5*3)

# x=5
# (x**2) + (x**3) + (x+2) - (x/2)

# uang = 30000
# if uang >= 25000:
#     print("cukup")
# else:
#     print("tidakcukup")

# price = 25000
# uang = 10000
# if price == uang:
#     print("uang pas")
# elif price < uang:
#     print("uang lebih")
# else:
#     print("uang kurang")

# nilai = 75
# if nilai >= 90:
#   print("Nilai A")
# elif 70 < nilai < 90:
#   print("Nilai B")
# else:
#   print("Nilai C")


# price = 20000
# kondisi = "baik"
# if price >= 20000:
#   print("uang pas")
#   if kondisi == "baik":
#     print("Uang Laku")
#   else:
#     print("Uang Tidak Laku")
# else:
#   print("uang tidak cukup")

# for i in range(10):
#   print("Saya berjanji tidak mengulanginya lagi")

# j=10
# while j > 0:
#   print(j)
#   j -= 1

# j=0
# while j<10:
#   print(j)
#   j += 1

# total = 0
# for i in range(2,6):
#   total = total + i
#   print(total)

# total = 0
# for i in range(1,1000):
#   total = total + i
#   print(total)

# for i in range(1 ,999, 3):
#   print(i, end=" ")

# for i in range(1,6):
#   for j in range(1, 3):
#     print("ini lorong ke", i ," Kamar Ke - ", j)

# lanjut = True
# while(lanjut):
#   option = input("Lanjut atau tidak Y/N : ")
#   if(option == 'n'):
#     lanjut = False
#     print("Program berhenti")
#   elif(option == 'y'):
#     lanjut = True
#     print("Makasih Udah Main")

# //CONTOH
# username = "Universitas"
# password = "Pertamina"
# kesempatan = 3

# while kesempatan > 0:
#   username_user = input(" Masukkan Username : ")
#   password_user = input(" Masukkan Password : ")
#   if password == password_user and username == username_user:
#     print(" Berhasil Login! ")
#     break
#   else:
#     kesempatan -= 1
#     print( "Login gagal dan kesempatan anda tinggal {} kali lagi ". format(kesempatan))
#     exit()

# //FUNGSI
# def perjumlahan(angka1, angka2):
#   return angka1 + angka2

# hasil = perjumlahan(10,2)
# print(hasil)

# def fungsi(x):
#   return (x**2) + (x**3) + (x+2) - (x/2)

# hasil = fungsi(7)
# print(hasil)
# Out:
# 397.5
